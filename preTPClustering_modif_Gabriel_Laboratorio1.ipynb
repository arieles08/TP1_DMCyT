# %% [markdown]
# ![img.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ##      **_Data mining en Ciencia y Tecnología_**
# #                2do cuatrimestre 2022
#
# # Procesamiento de imágenes (pre TP1)

# %%
pip install Clustimage

# %%
from clustimage import Clustimage
import matplotlib.pyplot as plt
import pandas as pd
import random
import os
import numpy as np

# %%
# Accessing My Google Drive
# Lista de archivos de flores
from google.colab import drive
drive.mount('/content/drive')
# !gdown --id
image_path = "/content/drive/MyDrive/Maestría - Ciencia de Datos/Colab Notebooks/DMCyT/flower_images" #PONER EL PATH DE CADA UNO
#image_path = "drive/My Drive/flower_images/flower_images" #PONER EL PATH DE CADA UNO
#Creo una lista con todos los nombres de las imágenes que se encuentran en la carpeta(png)
path = sorted([os.path.join(image_path, file)
                          for file in os.listdir(image_path )
                          if file.endswith('.png')])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# usage: gdown [-h] [-V] [-O OUTPUT] [-q] [--fuzzy] [--id] [--proxy PROXY]
#              [--speed SPEED] [--no-cookies] [--no-check-certificate]
#              [--continue] [--folder] [--remaining-ok]
#              url_or_id
# gdown: error: the following arguments are required: url_or_id

# %% [markdown]
# ## Las  imágenes son básicamente matrices
# Mínimo elemento de la matriz se conoce como pixel.
# Cada pixel es un dígito está entre (0,255) *(8 bits)*
#
# ![02-pixel.jpg](data:image/jpeg;base64,...)

# %%
cl = Clustimage()
img = cl.imread(path[0], dim=(128,128),colorscale=1) #Levanta la imagen
print(img)
len(img)
imagen = img.reshape(128,128,3)
plt.imshow(imagen)
plt.axis('off')
# Out:
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [ 10  22  13 ...  78  74 117]
# (-0.5, 127.5, 127.5, -0.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
labels=pd.read_csv("/content/drive/MyDrive/Maestría - Ciencia de Datos/Colab Notebooks/DMCyT/flower_images/flower_labels.csv")

# %%
labels
# Out:
#          file  label
# 0    0001.png      0
# 1    0002.png      0
# 2    0003.png      2
# 3    0004.png      0
# 4    0005.png      0
# ..        ...    ...
# 205  0206.png      6
# 206  0207.png      0
# 207  0208.png      4
# 208  0209.png      6
# 209  0210.png      1
#
# [210 rows x 2 columns]

# %%
labels.loc[:,"file"]=range(0, 210)

# %%
ejemplos
# Out:
# [0, 5, 2, 30, 21, 24, 6, 13, 35, 37]

# %%
ejemplos=list(range(10))
for i in range(10):
  ejemplos[i] = labels.loc[(labels['label'] == i)].iloc[0]['file']

# %%
ejemplos
# Out:
# [0, 5, 2, 30, 21, 24, 6, 13, 35, 37]

# %%
plt.figure(figsize = (17,8))
for i in range(len(ejemplos)):
  cl = Clustimage()
  img = cl.imread(path[ejemplos[i]], dim=(128,128),colorscale=1) #Levanta la imagen
  plt.subplot(2,5,i+1)
  plt.title("clase" + ' ' + str(i))
  imagen = img.reshape(128,128,3)
  plt.imshow(imagen)
  #plt.axis('off')

plt.tight_layout()
# Out:
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]

# %% [markdown]
# La imagen se trata como un array. Puedo elegir qué parte mostrar

# %%
plt.figure(figsize = (17,8))

  cl = Clustimage()
  img = cl.imread(path[ejemplos[i]], dim=(128,128),colorscale=1) #Levanta la imagen
  plt.subplot(2,5,i+1)
  plt.title("clase" + ' ' + str(i))
  imagen = img.reshape(128,128,3)
  plt.imshow(imagen)
  #plt.axis('off')

plt.tight_layout()

# %%
cl = Clustimage()
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen

imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')
plt.axis('off')
# Out:
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [19 20 22 ... 49 26 97]
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen
arr=img
img=np.array([min([num*2, 255]) for num in arr])
imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')

plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen
arr=img
img=np.array([max([num-100, 0]) for num in arr])
imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')

plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen
arr=img
img=np.array([round(num/255)*255 for num in arr])
imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')

plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen
arr=img
img=np.array([int(num>80)*255 for num in arr])
imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')

plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cl.imread(path[0], dim=(128,128),colorscale=0) #Levanta la imagen
arr=img
img=np.array([int(num>200)*255 for num in arr])
imagen = img.reshape(128,128)
plt.imshow(imagen, cmap='gray')

plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
round(num/255)

# %%
# Puedo seleccionar una región de la imagen
plt.imshow(imagen[3:30,3:30],cmap='gray')
plt.axis('off')

# Una forma de caracterizar la imagen es ver cómo es la distribución de los pixels 
plt.hist(img,bins=10,color='grey',edgecolor='k')
plt.xlabel('pixel values')
# Out:
# Text(0.5, 0, 'pixel values')

# %% [markdown]
# Como cualquier matriz, la imagen se puede rotar o girar

# %%
imagen_rotada = np.flipud(imagen) #Reverse the order of elements along axis 0 (up/down).
plt.subplot(2,1,1)
plt.imshow(imagen_rotada,cmap='gray')
plt.axis('off')
plt.subplot(2,1,2)
plt.imshow(imagen,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %% [markdown]
# ## Para suavizar una imagen o para reducir el ruido se usan filtros sobre las imágenes.
#
# ![filtros.PNG](data:image/png;base64,...)

# %%
from   import median_filter
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.median_filter.html
imagen_filtrada = median_filter(imagen,size=2)

plt.subplot(1,2,1)
plt.imshow(imagen, cmap='gray')
plt.axis('off')
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(imagen_filtrada, cmap='gray')
plt.axis('off')
plt.title('Filtrada')
# Out:
# Text(0.5, 1.0, 'Filtrada')

# %% [markdown]
# ## Las imágenes a color
# 1 dimensión más  ⟶ RGB
# ![colores.PNG](data:image/png;base64,...)

# %%
 img = cl.imread(path[0], dim=(128,128),colorscale=1)
 len(img)
 imagen_color=img.reshape(128,128,3)
 plt.imshow(imagen_color)
 plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
colores =['red','green','blue']
for n,cs in enumerate(colores):
  monocol=imagen_color[:,:,n]
  plt.hist(monocol.reshape(128*128,1),color=cs,bins=10,edgecolor='k',alpha=0.5,label=cs)
  plt.legend()
